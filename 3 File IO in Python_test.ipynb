# %% [markdown]
# ## **File I/O - Python notebook**

# %% [markdown]
# file I/O in Python:
#
# Tutorials Point: <a href="https://www.tutorialspoint.com/python/python_files_io.htm"><b>Python - Files I/O</b></a>
#
# #### File object methods
# ```
# * open(): opens a file; returns a file object
# * close(): closes an open file
# * read(): reads from an open file
# * readline(): reads a line from an open text file
# * readlines(): reads all lines from an open file, and stores each line in a list
# * write(): writes a string to a file
# * tell(): returns the current position of the file pointer (number of bytes from beginning of file)
# * seek(): changes the position of the file pointer
#
# ```

# %% [markdown]
# <div class="alert alert-block alert-info">
# Run this 'magic command' <code>%pwd</code> in code cell below - you should see what your current working directory is (i.e., where your Jupyter notebook lives).
# </div>

# %%
# code cell 1

# commands preceded by a % are known as 'magic commands'
# FMI about line magics, see https://www.tutorialspoint.com/jupyter/ipython_magic_commands.htm
# %pwd

# %% [markdown]
# Copy and paste in this pathname wherever you need it in the cells below.
#
# <div class="alert alert-block alert-info">
# The magic command <code>%ls</code> lists the current contents of your working directory - run the following cell to see what it does.
# </div>

# %%
# code cell 2

# commands preceded by a % are known as 'magic commands'
# FMI about line magics, see https://www.tutorialspoint.com/jupyter/ipython_magic_commands.htm
# %ls

# %% [markdown]
# <div class="alert alert-block alert-info">
# Now, run the cell below, but replace my pathname with the pathname you got from running <code>pwd</code> earlier. Make sure that your pathname string is <b>terminated</b> by an <b>escaped backslash (double backslash)</b> if you're using a Windows O/S (operating system), or a <b>single forward slash</b> if you're using Mac OS.
# </div>

# %%
# code cell 3

# Windows: the pathname is a raw string (no need to escape the backslashes)
#pathname = r'C:\Users\EricKawamoto\Dropbox\Documents\teaching\BATS\COS301 A block\'  # replace with your pathname
# Mac OS
#pathname = '/Users/ehk/Dropbox/Documents/teaching/BATS/COS301 A block/'

f = open(pathname + 'newTextFile.txt', 'w') # open for writing only
f.write('Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.\n')
f.write('Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.\n')
f.close()

# after running the above, your directory listing should now show a new entry, 'newTextFile.txt'
# %ls

# %%
# code cell 4

# now, open the file for append, and write a new line to it
# Windows: the pathname is an ordinary string, which require backslashes to be escaped
pathname = 'C:\\Users\\EricKawamoto\\Dropbox\\Documents\\teaching\\BATS\\COS301 A block\\' # replace with your pathname
# Mac OS
#pathname = '/Users/ehk/Dropbox/Documents/teaching/BATS/COS301 A block/' # replace with your pathname

f = open(pathname + 'newTextFile.txt', 'r+') # open for reading and writing
for line in f:
    print(line)
f.write('Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur.\n')
f.close()

f = open(pathname + 'newTextFile.txt', 'r')
L1 = f.readlines()
print(L1)
f.close()

# %% [markdown]
# <div class="alert alert-block alert-info">
# On your own laptop, using a text editor like Notepad, <a href="https://notepad-plus-plus.org/"><b>Notepad++</b></a>, or <a href="https://www.sublimetext.com/"><b>SublimeText</b></a> in Windows; or TextEdit or <a href="https://www.sublimetext.com/"><b>SublimeText</b></a> in macOS (unless you're a pro who knows how to use <code>vi</code> or <code>vim</code> at the command line), create a text file called <code>mywords.txt</code> in the same directory as you've been using above, and put some lines of text of your own choosing in it (nontrivial: at least a couple of sentences, one on each line, please). Then, run the code in the cell below.
# </div>

# %%
# code cell 5

# Windows
pathname = 'C:\\Users\\EricKawamoto\\Dropbox\\Documents\\teaching\\BATS\\COS301 A block\\'  # replace with your pathname
# Mac OS
#pathname = '/Users/ehk/Dropbox/Documents/teaching/BATS/COS301 A block/' # replace with your pathname

f = open(pathname + 'mywords.txt', 'r')
L1 = f.readlines()
print(L1)
f.close()

# %% [markdown]
# #### String methods in Python
#
# there are certainly more methods than the selection listed here; see https://www.w3schools.com/python/python_ref_string.asp for an exhaustive list
#
# | Method | Description |
# | --: | :-- |
# | ```count()``` | Returns the number of times a specified value occurs in a string |
# | ```find()``` | Searches the string for a specified value and returns the position of where it was found |
# | ```format()``` | Formats specified values in a string |
# | ```index()``` | Searches the string for a specified value and returns the position of where it was found |
# | ```isalnum()``` |	Returns ```True``` if all characters in the string are alphanumeric |
# | ```isalpha()``` |	Returns ```True``` if all characters in the string are in the alphabet |
# | ```isascii()``` |	Returns ```True``` if all characters in the string are ascii characters |
# | ```isdecimal()``` |	Returns ```True``` if all characters in the string are decimals |
# | ```isdigit()``` |	Returns ```True``` if all characters in the string are digits |
# | ```islower()``` |	Returns ```True``` if all characters in the string are lower case |
# | ```isnumeric()``` | Returns ```True``` if all characters in the string are numeric |
# | ```isspace()``` | Returns ```True``` if all characters in the string are whitespaces |
# | ```isupper()``` | Returns ```True``` if all characters in the string are upper case |
# | ```join()``` | Converts the elements of an iterable into a string |
# | ```lower()``` | Converts a string into lower case |
# | ```lstrip()``` | Returns a left trim version of the string |
# | ```replace()``` | Returns a string where a specified value is replaced with a specified value |
# | ```rfind()``` | Searches the string for a specified value and returns the last position of where it was found |
# | ```rindex()``` | Searches the string for a specified value and returns the last position of where it was found |
# | ```rstrip()``` | Returns a right trim version of the string |
# | ```split()``` | Splits the string at the specified separator, and returns a list |
# | ```splitlines()``` | Splits the string at line breaks and returns a list |
# | ```strip()``` | Returns a trimmed version of the string |
# | ```upper()``` | Converts a string into upper case |
#
# the use of a few of these will be illustrated in the code cell below

# %%
# code cell 6

pangram = "'The quick brown fox jumps over the lazy dog.'"
print(pangram + ' is a pangram.')
print('the letter \'e\' occurs', end=" ")
print(pangram.count('e'), end=" ")
print('times')

print('the letter \'e\' occurs at positions', end=" ")
i1 = pangram.find('e')
i2 = pangram.find('e', i1 + 1)
i3 = pangram.find('e', i2 + 1)
i4 = pangram.rfind('e')
print(str(i1) + ', ' + str(i2) + ', ' + str(i3) + ', and ' + str(i4))
print()

print('i can also find the indices of where the letter \'e\' occurs using index():', end = " ")
j1 = pangram.index('e')
j2 = pangram.index('e', j1 + 1)
j3 = pangram.index('e', j2 + 1)
j4 = pangram.rindex('e')
print(str(j1) + ', ' + str(j2) + ', ' + str(j3) + ', and ' + str(j4))
print()

print('is \'X\' in pangram? ' + str('X' in pangram))
print('\'X\' occurs ' + str(pangram.count('X')) + ' times in pangram')
print('the letter \'X\' occurs at index ' + str(pangram.find('X')) + ', which means "not found"')
print()

pList = pangram.split()
print('pangram as a list: ' + str(pList))
pStr = ' '.join(pList) 
print('pList as a string: ' + pStr)
print()

print('pangram is all ASCII characters: ' + str(pangram.isascii()))
print('pangram is all alphanumeric characters: ' + str(pangram.isalnum()))
print('now replace single quotes with nothing: ' + str(pangram.replace("'", "")))
pangram2 = pangram.replace("'", "")
print('pangram2 = ' + pangram2)
print('now replace period with newline: ' + str(pangram2.replace(".", "\n")))
pangram3 = pangram2.replace(' ', '').strip()
print('now replace spaces in pangram2 with nothing: ' + pangram3)
print('pangram3 is all alphabetic characters: ' + str(pangram3.isalpha()))
print('pangram3 is all alphanumeric characters: ' + str(pangram3.isalnum()))
print()

pangram4 = pangram3.upper()
print(pangram4)
print(pangram4.lower())

# %% [markdown]
# Another thing that often needs to be done when reading lines of text from a file is to strip extraneous newline characters (<code>\n</code>) and quotes (<code>'</code>, <code>"</code>) from them, especially when using <code>readlines()</code> to write those lines of text to a list. This is where string methods come in handy.
#
# <div class="alert alert-block alert-info">
# Now, using what you learned about navigating your file system and string functions: <br>
#
# 1. In <code>main()</code> below, open the text file <code>mywords.txt</code> that you created in code cell #5 above. <br>
#
# 2. Read its lines into a list <code>L1</code>, and print that list; don't forget to <code>close()</code> the file after doing this! <br>
#
# 3. Use a <b>loop</b> to print <b>each element</b> of <code>L1</code>; don't just print the entire list as you did in #2! Each element should be a line of text separated by a blank line - this is caused by a newline character (<b>nonprinting</b> <code>'\n'</code>) terminating each line. <br>
#
# 4. In another loop, print each element of <code>L1</code> again, but this time, strip the newline character from each line (hint: use <code>rstrip()</code>). <br>
#
# 5. Now, use <code>str()</code> to obtain the <b>string representation</b> of the list <code>L1</code>, assign it to a variable, and print it. <br>
#
# 6. This string should have leading and trailing brackets. Remove them and print the resulting string (hint: use <code>strip()</code>). <br>
#
# 7. This string should now consist of strings delimited by quotes, separated by commas. Remove the quotes and print the resulting string (hint: use <code>replace()</code>). <br>
#
# 8. This string should now consist of phrases ending in <code>\n</code> characters (here, the backslash is printed literally). Remove those as well, and print the resulting string. <br>
#
# 9. You should now have a series of comma-separated phrases. Turn them back into a list of strings <code>L2</code>, and print <code>L2</code> (hint: use <code>split()</code>). <br>
#
# 10. Convert the elements of <code>L2</code> into a single string with a space separating each list element (hint: use <code>join()</code>), and print the resulting string.
# </div>

# %%
# code for file read and string exercises

def main():
    pass


# remember to invoke main()!
main()

# %% [markdown]
# Here is a real-world example of searching a file and parsing its text to extract only the details you're interested in. If you can do this without a file, you are <b>webscraping</b>. Suppose that you've looked up the current weather conditions at Portland, ME using the National Weather Service website (<a href="https://www.weather.gov/"><b>https://www.weather.gov/</b></a>; enter "Portland, ME" in the search box, then go to the Current Conditions page.) Right-click on the page and choose "View Source". Then, select all HTML content (<code>CTRL-A</code>), copy it, and paste it into a text editor like Notepad2 or Sublime Text. (<b>DO NOT</b> use File → Save As.) Save this page as a text file, then do the following:
#
# <div class="alert alert-block alert-info">
#
# 1. Move your text file to a directory on your computer (preferably, the one you're using to store these Jupyter notebooks) and figure out the path to it, as in code cell #5 above. <b>It may help to view the contents of the file using a text editor like Notepad2 or SublimeText.</b> <br>
#
# 2. In the code cell below, open the file, read in the entire file (<code>f.read()</code>), and close the file. All contents of the file will be stored in a variable <code>S</code>, which is a string. Find and print the length of this string. <br>
#
# 3. Create a list of these five strings to search your file for: <code>findStr[0] = "Current conditions at"</code>, <code>findStr[1] = "Lat:"</code>, <code>findStr[2] = "Lon:"</code>, <code>findStr[3] = "myforecast-current-lrg"</code>, and <code>findStr[4] = "Last update"</code>. <br>
#
# 4. Create a list of variables to hold the indices at which these strings are found. Print the indices <code>i[0]</code> through <code>i[4]</code> at which <code>findStr[0]</code> through <code>findStr[4]</code> were found in the file. <br>
#
# 5. From index <code>i[0]</code>, find the first occurrence of <code>'">'</code>, then from there, find the first occurrence of <code>'\</'</code>, and save the indices where these are found - this will define the first string. <br>
#
# 6. From indices <code>i[1]</code> through <code>i[3]</code>, find the first occurrence of <code>'>'</code>, then from there, find the first occurrence of <code>'<'</code>, and save the indices where these are found - this will define the second, third, and fourth strings. <br>
#
# 7. From index <code>i[4]</code>, find the first occurrence of <code>'\<td\>'</code>, then from there, find the first occurrence of <code>'\</td\>'</code>, and save these indices where these are found - this will define the last string. <br>
#
# 8. Using the indices you found for <code>i[0]</code> for the first string, you should have something that looks like <code>Portland, Portland International Jetport (KPWM)</code> - this is your location. (Hint: use the slice notation <code>S[x:y]</code>.) <br>
#
# 9. For the second string, you should have something that looks like <code>43.64&amp;deg;N</code> - this is your latitude. <br>
#
# 10. For the third string, you should have something that looks like <code>70.3&amp;deg;W</code> - this is your longitude. <br>
#
# 11. For the fourth string, you should have something that looks like <code>38&amp;deg;F</code> - this is the current temperature in degrees Fahrenheit. <br>
#
# 12. For the fifth string, you should get something that looks like <code>13 Jan 8:51 pm EST</code> - this is the date and time of the last update of the temperature reading. <br>
#
# 13. Look up a different city using the same website, and copy the page source to a different file as you did earlier. Then, use the same code you wrote above to open it, extract and print out the same information. Copy, paste, and comment out the output in your code cell below. <br>
#
# <b>Extra challenge:</b><br>
# 1. What we have done here is "brute force", and certainly not the best way to scrape data from an HTML file. Install and import the Python package <code>beautifulsoup</code>, then use this <a href="https://www.geeksforgeeks.org/implementing-web-scraping-python-beautiful-soup/#"><b>https://www.geeksforgeeks.org/implementing-web-scraping-python-beautiful-soup/#</b></a> or any other resources to figure out how to do exactly what you did above using this HTML parser. <br>
#
# 2. There is a package <code>mmap</code> that enables you to use a memory-mapped file instead of a "physical" file that you have downloaded to your laptop's hard drive. Install and import <code>mmap</code> and figure out how to use this to do exactly what you have done above.
# </div>

# %%
# code for file I/O + webscraping exercise

def main():
    pass


# remember to invoke main()! 
main()

# %% [markdown]
# <div class="alert alert-block alert-info">
# This is an authentic exercise in data analysis using economic data that has been compiled into CSV files. The data you'll be using is from FRED® (Federal Reserve of St. Louis), a repository of data from governmental and other official agencies, research and statistical sources, etc. Below is a chart from a FRED® Blog entry about <a href="https://fredblog.stlouisfed.org/2014/03/unemployment-rates-by-educational-attainment/?utm_source=series_page&utm_medium=related_content&utm_term=related_resources&utm_campaign=fredblog"><b>unemployment rate vs. educational attainment</b></a>.
# </div>

# %% [markdown]
# <div>
# <img src="attachment:unempl_vs_educ_attain.png" width=550/>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# You will download time-series data for unemployment rates for those without a high school diploma, and for those high school graduates who have some college or associate degree. Then, you'll plot those two datasets on one graph. In a second code cell, you'll plot the two unemployment rates against each other (note that the rates for no HS diploma seem to be roughly twice those for those who have some college), and determine the correlation between the two. <br>
#
# Before doing this exercise, read about how to use the <code>csv</code> module in <a href="https://www.programiz.com/python-programming/reading-csv-files"><b>Reading CSV Files in Python</b></a>. Then: <br>
#
# 1. Navigate to <a href="https://fred.stlouisfed.org/series/LNS14027659"><b>https://fred.stlouisfed.org/series/LNS14027659</b></a> to find the data for unemployment rate for those without a HS diploma, and download that CSV file to the same directory where this notebook resides. <br>
#
# 2. Navigate to <a href="https://fred.stlouisfed.org/series/LNS14027689"><b>https://fred.stlouisfed.org/series/LNS14027689</b></a> to find the data for unemployment rate for those with some college or associate degree, and download that CSV file to the same directory where this notebook resides. <br>
#
# 3. In the code cell below, open one CSV file (use <code>with open("name_of_file.csv"):</code> and use <code>csv.reader()</code> to read the file line by line - this stores each line of the file as a list of strings. Do this with the other CSV file as well. (For more info about <code>with</code>, see <a href="https://builtin.com/software-engineering-perspectives/what-is-with-statement-python"><b>What is the <code>with</code> statement in Python?</b></a>.)<br>
#
# 4. Each line of the CSV file consists of two strings separated by a comma; the first line (row) contains headers (words), while all other lines (rows) contain a date and a floating-point value (read in as strings). For the first five lines (rows) of each CSV file, print out the list. <br>
#
# 5. Initialize two empty lists. In the loop that reads through each line of the CSV file, append to the first list an index number (integer), and append to the second list the unemployment rate (convert this string to a float). Be sure to <b>skip the first line (row)</b>, which contains text, not numbers. (For the purposes of this exercise, we will ignore the date information, and simply refer to each data point by index number. It's a chore to plot dates correctly.) <br>
#
# 6. Do what you did for #5 for the second CSV file. Then, verify that all four lists you created have the same number of elements. Again, skip the first row, which doesn't contain numbers. <br>
#
# 7. Use <code>matplotlib</code> to make a line plot of both datasets (unemployment rates) against the index number <b>on the same graph. Use a different color for each dataset.</b> <br>
#
# 8. Be sure to give your plot a title, and label the axes with the quantities they represent. (For instance, the y axis is unemployment rate in percent, while the x axis is an index number.) <br>
# </div>

# %% [markdown]
# Your plot (before adding axis labels) should look something like this:
# <div>
# <img src="attachment:unemp.png" width=450/>
# </div>

# %%
# exercise for reading unemployment data from CSV files, then plotting them 

from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import csv

def main():
    pass


# remember to invoke main()!
main()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Extra challenge:</b><br>
# You may have noticed that, for duration covered by the data, the unemployment rate for non-HS school graduates is about 1.5 to 2x the rate for those with some college or associate degree. You'll determine this more precisely by graphing the two unemployment rates against each other in a correlation plot, then determining the slope of a best-fit line through the points. <br>
#
# 1. In a new code cell, use the two lists that contain the unemployment rates (from #5 and #6 above), and plot the one for non-HS graduates ($y$) against the one for some college ($x$). Use a <b>scatter</b> plot for this, and color the points black. <br>
#
# 2. Use <code>linfit()</code> to calculate the slope (<code>m</code>), y-intercept (<code>b</code>), and correlation coefficient (<code>R2</code>). <br>
#
# 3. Then, create a list <code>xVals</code> of, say, 10 values between 0 and 20, then create a second list <code>yFitVals</code> with the same number of elements, where each element <code>yFitVal[i] = m * xVals[i] + b</code>. <br>
#
# 4. In the same plot you created for #1, add a <b>line</b> plot of <code>yFitVals</code> against <code>xVals</code>. Color this line red. <br>
#
# 5. Be sure to give this plot a title, label its axes, but also give it a legend containing the equation of the best-fit line and its $R^2$ value. <br>
# </div>

# %%
def linfit(xVals, yVals) -> tuple:
    slope = 0.
    yInt = 0.
    R2 = 0.
    
    nPts = len(xVals)
    if len(yVals) != nPts:
        print("error: sizes of xVals and yVals are unequal!")
    elif nPts < 2:
        print("error: xVals and yVals must have at least two points!")
    else:
        Sx = 0.
        Sy = 0.
        Sxx = 0.
        Sxy = 0.
        Syy = 0.
        for x in xVals:
            Sx += x
            Sxx += x * x
        i = 0
        for y in yVals:
            Sy += y
            Syy += y * y
            Sxy += y * xVals[i]
            i += 1
        denom1 = nPts * Sxx - Sx * Sx
        num1 = nPts * Sxy - Sx * Sy
        slope = num1 / denom1
        yInt = (Sy * Sxx - Sx * Sxy) / denom1
        denom2 = (nPts * Sxx - Sx * Sx) * (nPts * Syy - Sy * Sy)
        R2 = num1 * num1 / denom2
        
    return (slope, yInt, R2)

# %%
# extra challenge: plot the two unemployment rates against each other
# then, determine their correlation (slope and R^2) using linfit()
# RUN THE CELL ABOVE BEFORE RUNNING THIS ONE!

from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import csv

def main():
    pass


# remember to invoke main()!
main()

# %% [markdown]
# **binary files**
#
# Info about the bitmap file format: https://www.ece.ualberta.ca/~elliott/ee552/studentAppNotes/2003_w/misc/bmp_file_format/bmp_file_format.htm
#
#
# file ```bmp_24.bmp``` (200x200 pixel bitmap file, 24 bpp, file size 120,054 bytes)
#
# ![bmp_24.bmp](data:image/bmp;base64,...)

# %% [markdown]
# use of ```seek(offset, whence)```
#
# ```offset```:  number of bytes from ```whence```
#
# ```whence```:  0 = beginning of file, 1 = current file pointer position, 2 = end of file

# %%
# code cell 8

# 200x200 pixel 3-color bitmap file
# size 120,054 bytes (0x01D4F6 in hex), 24 bits per pixel (bpp)

def main(fName):
    f = open(fName, 'rb')  # open file for read in binary mode
    print('opened file ' + fName + '\n')

    print('current file pointer position: ' + str(f.tell()))
    x = f.read(2)  # read two bytes at current pointer location
    print("first two bytes of file are 'BM' at offset 0: " + str(x) + '\n')

    print('current file pointer position: ' + str(f.tell()))
    x = f.read(4)  # read four bytes at current pointer location
    print('file size in bytes (4 bytes at offset 2): ' + str(x))
    print('file size as a decimal:' , int.from_bytes(x, "little"), '\n')

    f.seek(10, 0)  # move pointer to 10 bytes from start
    print('current file pointer position: ' + str(f.tell()))
    x = f.read(4)  # read four bytes at current pointer location
    print('offset to bitmap data (4 bytes at offset 10): ' + str(x))
    print('offset to bitmap data as a decimal:' , int.from_bytes(x, "little"), '\n')
    
    f.seek(18, 0)  # move pointer to 18 bytes from start
    print('current file pointer position: ' + str(f.tell()))
    x = f.read(4)  # read four bytes at current pointer location
    print('horiz width (4 bytes at offset 18): ' + str(x))
    print('horiz width as a decimal:' , int.from_bytes(x, "little"), '\n')

    f.seek(0, 1)   # move pointer 0 bytes from current location
    print('current file pointer position: ' + str(f.tell()))
    x = f.read(4)  # read four bytes at current pointer location
    print('vert height (4 bytes at offset 22): ' + str(x))
    print('vert height as a decimal:' , int.from_bytes(x, "little"), '\n')

    f.seek(2, 1)   # move pointer 2 bytes from current location
    print('current file pointer position: ' + str(f.tell()))
    x = f.read(2)  # read two bytes at current pointer location
    print('bits per pixel (2 bytes at offset 28): ' + str(x))
    print('bits per pixel a decimal:' , int.from_bytes(x, "little"), '\n')
    
    f.close()

    
# replace with your own pathname to bmp_24.bmp
# Windows
#fName = "C:\\Users\\EricKawamoto\\Dropbox\\Documents\\teaching\\BATS\\COS301 B block\\bmp_24.bmp" 
# Mac OS
#pathname = '/Users/ehk/Dropbox/Documents/teaching/BATS/COS301 A block/bmp_24.bmp' # replace with your pathname
pathname = '/Users/ehk/Dropbox/Documents/teaching/BATS/COS301 A block/bmp_24.bmp' # replace with your pathname

# remember to invoke main()!
main(pathname)

# %% [markdown]
# Browser-based hex viewer for files: <b>https://hexed.it/</b> : simply drag a file into the browser window, and view its contents. Try using it to open a text file, then a binary file (an image, an executable file, etc.) <br>

# %% [markdown]
# <div class="alert alert-block alert-info">
# This is an exercise in reading from a binary file. Note that, for a "vanilla" (uncompressed, no palette) 24 bits-per-pixel (bpp) bitmap image file, each pixel's RGB (red/green/blue) value is stored as BGR, with 8 bits (1 byte) per color. Moreover, <b>the first pixel in the file is at the bottom left of the image</b> (that is, pixels are stored from bottom to top, left to right). See <a href="https://en.wikipedia.org/wiki/BMP_file_format#Pixel_array_(bitmap_data)"><b>Pixel array (bitmap data)</b></a> for more info. (For an explanation that's MUCH easier to understand, see <a href="https://www.ece.ualberta.ca/~elliott/ee552/studentAppNotes/2003_w/misc/bmp_file_format/bmp_file_format.htm"<b>THE BITMAP FILE FORMAT</b></a>.) <br>
#
# Using the same 200x200 pixel file <code>bmp_24.bmp</code> as above, you will determine the color of pixels at three locations of the image: <br>
# * row 200, column 100 <br>
# * row 100, column 150 <br>
# * row 50, column 100 <br>
#
# To do this, you will write a function <code>readPixelFromBMPFile(f, row, col)</code> that takes a file object, row and column numbers (as integers), and add default arguments <code>dataOffset=54</code>, <code>pixelPerRow=200</code>, and <code>bytesPerPixel=3</code> which will: <br>
# 1. use <code>seek()</code> to move the file pointer  to the offset that corresponds to the row and column of the pixel whose value you want to retrieve (don't forget to add the data offset!) <br>
# 2. read the pixel data at the file pointer's location <br>
# 3. return the data value <br>
#
# Then, in your <code>main()</code>, open the file <code>bmp_24.bmp</code> as above, and call this function to find the color value of the pixel at each of the three locations given above, and print out each location (row, col) and its color value. Verify that the colors match what the image shows for those locations. Be sure to close the file after opening it! <br>
# </div>

# %%
# code for bitmap-reading exercise
# pixels are stored as BGR, not RGB
# pixels coordinates are referenced from bottom left (bottom up, left to right): 
# https://en.wikipedia.org/wiki/BMP_file_format#Pixel_array_(bitmap_data)
# https://www.ece.ualberta.ca/~elliott/ee552/studentAppNotes/2003_w/misc/bmp_file_format/bmp_file_format.htm
# (row 200, col 1 is the first pixel)

def readPixelFromBMPFile(f, row, col, dataOffset=54, pixelPerRow=200,  bytesPerPixel=3):
    pass


def main(fName):
    f = open(fName, 'rb')  # open file for read in binary mode
    print('opened file ' + fName + '\n')
    
    row = 200
    col = 100
    x = readPixelFromBMPFile(f, row, col)
    print('pixel in file at row ' + str(row) + ', col ' + str(col) + ' is:', str(x))

    row = 100
    col = 150
    x = readPixelFromBMPFile(f, row, col)
    print('pixel in file at row ' + str(row) + ', col ' + str(col) + ' is:', str(x))
    
    row = 50
    col = 100
    x = readPixelFromBMPFile(f, row, col)
    print('pixel in file at row ' + str(row) + ', col ' + str(col) + ' is:', str(x))
    
    f.close()


# replace fullname with your own pathname to bmp_24.bmp
main(fullname)

# %%
! conda install Pillow

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Extra challenge:</b> Here, you will create a UDF that converts the pixels of an image to greyscale values, then maps those values to a greyscale ramp of ASCII characters. Your code will call this function to take an image, display it, convert it to a list of ASCII characters, and print it out. (This is how images were rendered on a terminal or on a line printer before high-resolution monitors and printers became available.) <br>
#
# 1. Download the image file <code>house_c256.png</code> to a directory on your laptop. Then, use <code>PIL.Image()</code> (see <a href="https://omz-software.com/pythonista/docs/ios/Image.html"><b>The Image Module</b></a>) to open the file, and assign what it returns to a variable <code>img</code>. <br>
# 2. Convert this image to greyscale (mode <code>'L'</code>) using <code>Image.convert()</code> (see <a href="https://holypython.com/python-pil-tutorial/color-modes-explained-for-digital-image-processing-in-python-pil/"><b>Color Modes Explained for Digital Image Processing in Python (PIL)</b></a>). <br>
# 3. Create a UDF <code>mapPixelToASCII()</code> that takes the greyscale image as its only input, and returns a list of characters:
#     - Use the greyscale image's <code>getdata()</code> method to retrieve all of its raw pixel data as a list of bytes <br>
#     - Determine the maximum and minimum values of this list, and print them out <br>
#     - Determine how many levels are in <code>cGreyRamp</code>, the given greyscale ramp (that is, how many characters are in this string)
#     - Loop through each byte in your list and scale its value to the range of values in your greyscale ramp
#     - Round each value to the nearest integer, then use this as the index of your greyscale ramp to convert each raw image byte to an ASCII character.
#     - Collect these characters in a list, and have your UDF return it. <br><br>
#
# 4. Create a second UDF <code>printChars()</code> that takes the list of ASCII characters as an input, the original size of the image (a <code>(wid, hgt)</code> tuple), and a parameter <code>skip=0</code>. This function will contain two loops to print out the characters row by row and element by element, skipping every <code>skip</code> rows or elements (columns). You can set this parameter so that the ASCII image is no more than about 100 characters wide (so that it fits in the output window below the code cell.) <br>
# 5. In your <code>main()</code>, assign a pathname to your image file to a string, call <code>mapPixelToASCII()</code> to convert its data to a list of characters, use <code>matplotlib.imshow()</code> to display the image in its original form (don't forget to call <code>.show()</code>), then call <code>printChars()</code> to print out the ASCII version of your image. <br>
# 6. Upload an image of your own, and try your code on it!
# </div>

# %%
# https://holypython.com/python-pil-tutorial/color-modes-explained-for-digital-image-processing-in-python-pil/
# https://omz-software.com/pythonista/docs/ios/Image.html
# https://note.nkmk.me/en/python-opencv-pillow-image-size/

from PIL import Image
import matplotlib.pyplot as plt

def mapPixelToASCII(greyImg) -> list:
    # cGreyRamp is a set of ASCII characters that render from dark to light
    cGreyRamp = r"$@B%8&WM#*oahkbdpqwmZO0QLCJUYXzcvunxrjft/\|()1{}[]?-_+~<>i!lI;:,\"^`'. "
    pass


def printChars(asciiImage, size, skip=0, x0=0, y0=0):
    pass


def main():
    pass


# remember to invoke main()!
main()

# %% [markdown]
# In this final exercise, you will roll a number ```nDice``` of dice a number ```nRolls``` times, then write to each line of an output file the values of each dice per roll, and the sum of those values. You will also create a dictionary that will be a histogram of <b>just the sums</b> (that is, the frequency of occurrence for each outcome of rolling ```nDice``` dice). As the number of rolls ```nRolls``` increases, the shape of the histogram should approach that of a binomial distribution. See <a href="https://demonstrations.wolfram.com/RollingMultipleDice/"><b>Rolling Multiple Dice</b></a> for more info. <br>
#
# <div class="alert alert-block alert-info">
# Now, you try! Write a program that: <br>
#
# 1. Asks the user to enter the number (<code>nDice</code>) of six-sided dice (d6, in gaming parlance) to roll, and how many times (<code>nRolls</code>) to roll them <br>
# 2. Asks the user to supply a (path)name for a file to write output to <br>
# 3. Uses a list to store the values of each of the <code>nDice</code> dice for each roll <br>
# 4. Appends to the end of this list the sum of the values of the <code>nDice</code> dice for each roll <br>
# 5. Prints that list to the screen (suppress or truncate this output if <code>nRolls</code> is large) <br>
# 6. Opens the output file <br>
# 7. Writes the data to this file: <code>nRolls</code> lines, each line being a string of comma-separated values of each of the <code>nDice</code> dice per roll, followed by the sum of all <code>nDice</code> dice per roll <br>
# 8. Closes the file. <br>
#
# View the contents of the file to make sure that it's what you expect; then run it with <code>nDice</code> small (say, 5 dice) and <code>nRolls</code> large (say, 1000 rolls). Then, <br>
#
# 9. Create a histogram (frequency of each possible value that rolling <code>nDice</code> dice can take) of the sums (the last entry in each line of the file) in the form of a dictionary <br>
# 10. Print that dictionary to the screen <br>
# 11. Open the file you created above, write the histogram <b>to the end of the file</b> (that is, DO NOT overwrite the file!), and then close it. <br>
# 12. Add a code cell, and print out the contents of your file. (Again, truncate the output if you have a large number of rolls.) <br>
# 13. Submit the file you created in this exercise along with this notebook. <br>
#
# Your dialog and outputs should resemble this:
# <pre>
# Enter the number of six-sided dice to roll: 5
# Enter the number of times to roll them: 5
# Enter a pathname for the file: C:\\Users\\EricKawamoto\\Dropbox\\Documents\\COS301 B block\\dice.txt
#
# screen output:
# [3, 5, 2, 1, 2, 13]
# [3, 2, 2, 1, 5, 13]
# ...
# [3, 6, 2, 6, 2, 19]
# [4, 4, 5, 5, 6, 24]
# [3, 6, 4, 6, 3, 22]
#
# {5: 4, 6: 10, 7: 17, ..., 28: 12, 29: 6, 30: 3}
#
# contents of dice.txt:
# 3, 5, 2, 1, 2, 13
# 3, 2, 2, 1, 5, 13
# ...
# 3, 6, 2, 6, 2, 19
# 4, 4, 5, 5, 6, 24
# 3, 6, 4, 6, 3, 22
#
# 5: 4
# 6: 10
# 7: 17
# ...
# 28: 12
# 29: 6
# 30: 3
# </pre>
#
# <b> Extra challenge:</b> Use <code>matplotlib</code> or <code>plotly</code> to represent your histogram as a bar graph. (You may need to figure out how to bin the possible outcomes, especially if you have a large number of dice.) Debug the program with small values of <code>nDice</code> and <code>nRolls</code>; once you get it working, then try increasing <code>nRolls</code> and seeing how the shape of the histogram evolves. <br>
# </div>
# </div>

# %%
# code for dice rolling exercise with file I/O

def main():
    pass
    

# remember to invoke main()!
main()
